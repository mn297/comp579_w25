# %%
# %pip install gymnasium matplotlib numpy pandas seaborn stable-baselines3[extra] ale-py gym-anytrading tqdm scipy scikit-learn dask-ml

# %%
import os
import random
import shutil
import heapq
import pickle
import psutil

import numpy as np

import modin.pandas as pd
import modin.config as cfg


import matplotlib.pyplot as plt
import torch
from torch import nn
from scipy.spatial import KDTree
import ta
import kagglehub

import gymnasium as gym
from gymnasium import spaces
import gym_anytrading

from stable_baselines3 import DQN, PPO, A2C, DDPG, SAC, TD3
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback
from stable_baselines3.common.vec_env import DummyVecEnv, VecMonitor, VecNormalize
from stable_baselines3.common.buffers import BaseBuffer
from stable_baselines3.common.type_aliases import ReplayBufferSamples
from stable_baselines3.common.buffers import ReplayBuffer

from typing import Union, Any, Optional

# from sklearn.preprocessing import MinMaxScaler
import dask.array as da
from dask_ml.preprocessing import MinMaxScaler


from signal import Signals
import time
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from tqdm.auto import tqdm
import stumpy
from numba import cuda
import IPython.display
import gc

# %% [markdown]
# ## PREPROCESSING

# %% [markdown]
# ### Get data and add technical features

# %%
import os, shutil
from modin.config import Engine

Engine.put("dask")  # Modin on Dask

import kagglehub, pandas as pd, dask.dataframe as dd
from dask.distributed import Client, progress
import ta, pyarrow as pa

print(pa.__version__)  # should be ≥ 10.0.1

client = Client()
print(client)


def add_ta(df: pd.DataFrame) -> pd.DataFrame:
    return ta.add_all_ta_features(
        df,
        open="open",
        high="high",
        low="low",
        close="close",
        volume="volume",
        fillna=True,
    )


path_sp500 = kagglehub.dataset_download(
    "gratefuldata/intraday-stock-data-1-min-sp-500-200821"
)
files_sp500 = os.listdir(path_sp500)
print("Files:", files_sp500)

output_path = "datasets/sp500_ta"

local_dir = "./datasets/sp500"
os.makedirs(local_dir, exist_ok=True)
for f in files_sp500:
    shutil.copy2(os.path.join(path_sp500, f), os.path.join(local_dir, f))
print("Files saved to", local_dir)

if os.path.exists(output_path):
    print("Dataset already exists.")
    ddf = dd.read_parquet(output_path)
else:
    print("Making dataset.")
    MAX_LOOKBACK = 256  # longest rolling window length
    # set index to datetime
    ddf = dd.read_csv(
        os.path.join(local_dir, "*.csv"),
        blocksize="64 MB",
        assume_missing=True,
        parse_dates={"datetime": ["date"]},
    ).set_index(
        "datetime",
        sorted=False,
        # drop=False
    )  # needed for map_overlap

    sample = ddf.head(MAX_LOOKBACK)  # small pandas DF (triggers 1 read)
    # make sure index is a column
    # if sample.index.name == "datetime":
    #     sample = sample.reset_index()
    meta = add_ta(sample).iloc[0:0]  # keep cols, drop rows

    ddf = ddf.map_overlap(
        add_ta,
        before=MAX_LOOKBACK - 1,
        after=0,
        meta=meta,
    )
    ddf = ddf.persist()
    progress(ddf)

    ddf.to_parquet(output_path, write_index=True)
    # ddf.to_csv("datasets/sp500_ta.csv", single_file=True, index=True)

    print("Finished TA feature generation with full look‑back safety.")
print("DataFrame columns:", ddf.columns.tolist())
ddf_fresh = ddf
# Out:
# 19.0.1
# <Client: 'tcp://127.0.0.1:60570' processes=8 threads=32, memory=93.71 GiB>
# Files: ['1_min_SPY_2008-2021.csv']
# Files saved to ./datasets/sp500
# Dataset already exists.
# DataFrame columns: ['Unnamed: 0', 'open', 'high', 'low', 'close', 'volume', 'barCount', 'average', 'volume_adi', 'volume_obv', 'volume_cmf', 'volume_fi', 'volume_em', 'volume_sma_em', 'volume_vpt', 'volume_vwap', 'volume_mfi', 'volume_nvi', 'volatility_bbm', 'volatility_bbh', 'volatility_bbl', 'volatility_bbw', 'volatility_bbp', 'volatility_bbhi', 'volatility_bbli', 'volatility_kcc', 'volatility_kch', 'volatility_kcl', 'volatility_kcw', 'volatility_kcp', 'volatility_kchi', 'volatility_kcli', 'volatility_dcl', 'volatility_dch', 'volatility_dcm', 'volatility_dcw', 'volatility_dcp', 'volatility_atr', 'volatility_ui', 'trend_macd', 'trend_macd_signal', 'trend_macd_diff', 'trend_sma_fast', 'trend_sma_slow', 'trend_ema_fast', 'trend_ema_slow', 'trend_vortex_ind_pos', 'trend_vortex_ind_neg', 'trend_vortex_ind_diff', 'trend_trix', 'trend_mass_index', 'trend_dpo', 'trend_kst', 'trend_kst_sig', 'trend_kst_diff', 'trend_ichimoku_conv', 'trend_ichimoku_base', 'trend_ichimoku_a', 'trend_ichimoku_b', 'trend_stc', 'trend_adx', 'trend_adx_pos', 'trend_adx_neg', 'trend_cci', 'trend_visual_ichimoku_a', 'trend_visual_ichimoku_b', 'trend_aroon_up', 'trend_aroon_down', 'trend_aroon_ind', 'trend_psar_up', 'trend_psar_down', 'trend_psar_up_indicator', 'trend_psar_down_indicator', 'momentum_rsi', 'momentum_stoch_rsi', 'momentum_stoch_rsi_k', 'momentum_stoch_rsi_d', 'momentum_tsi', 'momentum_uo', 'momentum_stoch', 'momentum_stoch_signal', 'momentum_wr', 'momentum_ao', 'momentum_roc', 'momentum_ppo', 'momentum_ppo_signal', 'momentum_ppo_hist', 'momentum_pvo', 'momentum_pvo_signal', 'momentum_pvo_hist', 'momentum_kama', 'others_dr', 'others_dlr', 'others_cr']

# %%
ddf = ddf_fresh

# %% [markdown]
# ### Normalize volume

# %%
from dask_ml.preprocessing import MinMaxScaler

# 1. Identify the volume columns
volume_features = ["volume", "volume_obv", "volume_vwap"]

# 2. Build a boolean mask of rows where ALL volume_features are non‑null
mask = ddf[volume_features].notnull().all(axis=1)

# 3. Fit the scaler on the valid subset
scaler = MinMaxScaler()
scaler.fit(ddf[volume_features][mask])

# 4. Transform the entire column block (rows with any NaN stay NaN after transform)
scaled = scaler.transform(ddf[volume_features])

# 5. Drop the originals and overwrite with the scaled columns
ddf_scaled = ddf.drop(columns=volume_features)
# `scaled` has the same column names as volume_features by default:
ddf_scaled = ddf_scaled.assign(**{col: scaled[col] for col in volume_features})


# Compute each stat in parallel, then collect to pandas
mins = ddf_scaled[volume_features].min().compute()
means = ddf_scaled[volume_features].mean().compute()
maxs = ddf_scaled[volume_features].max().compute()

# Print them out
print("Scaled volume feature stats:")
for col in volume_features:
    print(f"{col:12s}  min={mins[col]:.4f}  mean={means[col]:.4f}  max={maxs[col]:.4f}")

# print(ddf_scaled.columns)
# Out:
# Scaled volume feature stats:
# volume        min=0.0000  mean=0.0082  max=1.0000
# volume_obv    min=0.0000  mean=0.4125  max=1.0000
# volume_vwap   min=0.0000  mean=0.4019  max=1.0000

# %% [markdown]
# ### Regular trading hours

# %%
# Extract hour and minute from the index for filtering
ddf["hour"] = ddf.index.hour
ddf["minute"] = ddf.index.minute

# 2. Filter for Regular Trading Hours (RTH)
rth_filter = (
    ((ddf["hour"] == 9) & (ddf["minute"] >= 30))
    | ((ddf["hour"] > 9) & (ddf["hour"] < 16))
    | ((ddf["hour"] == 16) & (ddf["minute"] == 0))
)
ddf = ddf.loc[rth_filter]

# 3. Reset index, but keep datetime as a column for feature access
ddf = ddf.reset_index()  # Now 'datetime' is a column
print(ddf.columns)

ddf_preprocessed = ddf
# Out:
# Index(['datetime', 'Unnamed: 0', 'open', 'high', 'low', 'close', 'volume',
#        'barCount', 'average', 'volume_adi', 'volume_obv', 'volume_cmf',
#        'volume_fi', 'volume_em', 'volume_sma_em', 'volume_vpt', 'volume_vwap',
#        'volume_mfi', 'volume_nvi', 'volatility_bbm', 'volatility_bbh',
#        'volatility_bbl', 'volatility_bbw', 'volatility_bbp', 'volatility_bbhi',
#        'volatility_bbli', 'volatility_kcc', 'volatility_kch', 'volatility_kcl',
#        'volatility_kcw', 'volatility_kcp', 'volatility_kchi',
#        'volatility_kcli', 'volatility_dcl', 'volatility_dch', 'volatility_dcm',
#        'volatility_dcw', 'volatility_dcp', 'volatility_atr', 'volatility_ui',
#        'trend_macd', 'trend_macd_signal', 'trend_macd_diff', 'trend_sma_fast',
#        'trend_sma_slow', 'trend_ema_fast', 'trend_ema_slow',
#        'trend_vortex_ind_pos', 'trend_vortex_ind_neg', 'trend_vortex_ind_diff',
#        'trend_trix', 'trend_mass_index', 'trend_dpo', 'trend_kst',
#        'trend_kst_sig', 'trend_kst_diff', 'trend_ichimoku_conv',
#        'trend_ichimoku_base', 'trend_ichimoku_a', 'trend_ichimoku_b',
#        'trend_stc', 'trend_adx', 'trend_adx_pos', 'trend_adx_neg', 'trend_cci',
#        'trend_visual_ichimoku_a', 'trend_visual_ichimoku_b', 'trend_aroon_up',
#        'trend_aroon_down', 'trend_aroon_ind', 'trend_psar_up',
#        'trend_psar_down', 'trend_psar_up_indicator',
#        'trend_psar_down_indicator', 'momentum_rsi', 'momentum_stoch_rsi',
#        'momentum_stoch_rsi_k', 'momentum_stoch_rsi_d', 'momentum_tsi',
#        'momentum_uo', 'momentum_stoch', 'momentum_stoch_signal', 'momentum_wr',
#        'momentum_ao', 'momentum_roc', 'momentum_ppo', 'momentum_ppo_signal',
#        'momentum_ppo_hist', 'momentum_pvo', 'momentum_pvo_signal',
#        'momentum_pvo_hist', 'momentum_kama', 'others_dr', 'others_dlr',
#        'others_cr', 'hour', 'minute'],
#       dtype='object')

# %% [markdown]
# #### RUN THIS CELL TO RESTORE DDF

# %%
# Restore ddf
ddf = ddf_preprocessed
print(ddf.columns)
# Out:
# Index(['datetime', 'Unnamed: 0', 'open', 'high', 'low', 'close', 'volume',
#        'barCount', 'average', 'volume_adi', 'volume_obv', 'volume_cmf',
#        'volume_fi', 'volume_em', 'volume_sma_em', 'volume_vpt', 'volume_vwap',
#        'volume_mfi', 'volume_nvi', 'volatility_bbm', 'volatility_bbh',
#        'volatility_bbl', 'volatility_bbw', 'volatility_bbp', 'volatility_bbhi',
#        'volatility_bbli', 'volatility_kcc', 'volatility_kch', 'volatility_kcl',
#        'volatility_kcw', 'volatility_kcp', 'volatility_kchi',
#        'volatility_kcli', 'volatility_dcl', 'volatility_dch', 'volatility_dcm',
#        'volatility_dcw', 'volatility_dcp', 'volatility_atr', 'volatility_ui',
#        'trend_macd', 'trend_macd_signal', 'trend_macd_diff', 'trend_sma_fast',
#        'trend_sma_slow', 'trend_ema_fast', 'trend_ema_slow',
#        'trend_vortex_ind_pos', 'trend_vortex_ind_neg', 'trend_vortex_ind_diff',
#        'trend_trix', 'trend_mass_index', 'trend_dpo', 'trend_kst',
#        'trend_kst_sig', 'trend_kst_diff', 'trend_ichimoku_conv',
#        'trend_ichimoku_base', 'trend_ichimoku_a', 'trend_ichimoku_b',
#        'trend_stc', 'trend_adx', 'trend_adx_pos', 'trend_adx_neg', 'trend_cci',
#        'trend_visual_ichimoku_a', 'trend_visual_ichimoku_b', 'trend_aroon_up',
#        'trend_aroon_down', 'trend_aroon_ind', 'trend_psar_up',
#        'trend_psar_down', 'trend_psar_up_indicator',
#        'trend_psar_down_indicator', 'momentum_rsi', 'momentum_stoch_rsi',
#        'momentum_stoch_rsi_k', 'momentum_stoch_rsi_d', 'momentum_tsi',
#        'momentum_uo', 'momentum_stoch', 'momentum_stoch_signal', 'momentum_wr',
#        'momentum_ao', 'momentum_roc', 'momentum_ppo', 'momentum_ppo_signal',
#        'momentum_ppo_hist', 'momentum_pvo', 'momentum_pvo_signal',
#        'momentum_pvo_hist', 'momentum_kama', 'others_dr', 'others_dlr',
#        'others_cr', 'hour', 'minute'],
#       dtype='object')

# %% [markdown]
# ### Filter dataset

# %%
reduce_dataset = True

if reduce_dataset:
    # define your cut‑off dates
    start, end = "2016-01-01", "2021-01-01"

    # boolean mask on the datetime column
    ddf = ddf[(ddf["datetime"] >= start) & (ddf["datetime"] < end)]

    # 1) get the year and date Series
    years = ddf["datetime"].dt.year
    dates = ddf["datetime"].dt.date

    # 2) find all unique years (small list)
    unique_years = years.unique().compute()

    # 3) for each year, filter & collect unique dates
    dates_per_year = {}
    for y in unique_years:
        mask = years == y
        #  .unique() on the filtered date‐series
        dates_per_year[y] = dates[mask].unique().compute()

    # 4) print
    for year, ds in sorted(dates_per_year.items()):
        print(year, ds)
start = ddf["datetime"].min().compute()
end = ddf["datetime"].max().compute()
print(f"Date range: {start} → {end}")

# 5. Select features and drop NaNs
feature_cols = [
    "datetime",
    "close",
    "trend_sma_fast",
    "trend_sma_slow",
    "trend_macd_diff",
    "trend_adx",
    "momentum_rsi",
    "momentum_ao",
    "volatility_atr",
    "volatility_bbw",
    "volatility_dcw",
    "volume_obv",
    "volume_vwap",
]

ddf = ddf[feature_cols].dropna()
print("DataFrame columns:", ddf.columns.tolist())
print(ddf.head())
print(len(ddf))
# Out:
# 2025-04-21 21:56:15,087 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 62a8520bc0c9e42d4861e93d02781d4e initialized by task ('shuffle-transfer-62a8520bc0c9e42d4861e93d02781d4e', 2) executed on worker tcp://127.0.0.1:60613
# 2025-04-21 21:56:17,252 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 62a8520bc0c9e42d4861e93d02781d4e deactivated due to stimulus 'task-finished-1745286977.251236'
# 2025-04-21 21:56:17,409 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 938e60bcb36e1a552787ea7641f463c9 initialized by task ('shuffle-transfer-938e60bcb36e1a552787ea7641f463c9', 2) executed on worker tcp://127.0.0.1:60613
# 2025-04-21 21:56:19,517 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 938e60bcb36e1a552787ea7641f463c9 deactivated due to stimulus 'task-finished-1745286979.5167317'
# 2025-04-21 21:56:19,737 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle b3cb788d69580bccfd49b484431a03d2 initialized by task ('shuffle-transfer-b3cb788d69580bccfd49b484431a03d2', 2) executed on worker tcp://127.0.0.1:60613
# 2025-04-21 21:56:21,659 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle b3cb788d69580bccfd49b484431a03d2 deactivated due to stimulus 'task-finished-1745286981.6580088'
# 2025-04-21 21:56:21,813 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 15cc9a53e0618f44c9ff4b7fd62c1012 initialized by task ('shuffle-transfer-15cc9a53e0618f44c9ff4b7fd62c1012', 2) executed on worker tcp://127.0.0.1:60613
# 2025-04-21 21:56:23,105 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 15cc9a53e0618f44c9ff4b7fd62c1012 deactivated due to stimulus 'task-finished-1745286983.1047678'
# 2025-04-21 21:56:23,251 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 18769235828d7a90f80e9d2671b12787 initialized by task ('shuffle-transfer-18769235828d7a90f80e9d2671b12787', 2) executed on worker tcp://127.0.0.1:60613
# 2025-04-21 21:56:24,542 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 18769235828d7a90f80e9d2671b12787 deactivated due to stimulus 'task-finished-1745286984.5364807'
# 2025-04-21 21:56:24,746 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 413e82d0a7947fc261a545a189e5365c initialized by task ('shuffle-transfer-413e82d0a7947fc261a545a189e5365c', 2) executed on worker tcp://127.0.0.1:60613
# 2025-04-21 21:56:25,990 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 413e82d0a7947fc261a545a189e5365c deactivated due to stimulus 'task-finished-1745286985.9890132'
# 2016 0     2016-01-13
# 1     2016-01-19
# 2     2016-01-29
# 3     2016-02-01
# 4     2016-02-03
#          ...
# 81    2016-12-09
# 82    2016-12-13
# 83    2016-12-14
# 84    2016-12-16
# 85    2016-12-27
# Name: datetime, Length: 252, dtype: object
# 2017 0     2017-01-03
# 1     2017-01-09
# 2     2017-01-18
# 3     2017-01-24
# 4     2017-01-27
#          ...
# 84    2017-12-21
# 85    2017-12-22
# 86    2017-12-26
# 87    2017-12-27
# 88    2017-12-28
# Name: datetime, Length: 251, dtype: object
# 2018 0     2018-01-03
# 1     2018-01-08
# 2     2018-01-09
# 3     2018-01-10
# 4     2018-01-11
#          ...
# 81    2018-11-30
# 82    2018-12-04
# 83    2018-12-12
# 84    2018-12-20
# 85    2018-12-26
# Name: datetime, Length: 251, dtype: object
# 2019 0     2019-01-07
# 1     2019-01-08
# 2     2019-01-09
# 3     2019-01-10
# 4     2019-01-11
#          ...
# 80    2019-11-27
# 81    2019-11-29
# 82    2019-12-16
# 83    2019-12-27
# 84    2019-12-31
# Name: datetime, Length: 252, dtype: object
# 2020 0     2020-01-03
# 1     2020-01-08
# 2     2020-01-09
# 3     2020-01-13
# 4     2020-01-16
#          ...
# 76    2020-12-07
# 77    2020-12-14
# 78    2020-12-17
# 79    2020-12-18
# 80    2020-12-22
# Name: datetime, Length: 253, dtype: object
# Date range: 2016-01-04 09:30:00 → 2020-12-31 16:00:00
# DataFrame columns: ['datetime', 'close', 'trend_sma_fast', 'trend_sma_slow', 'trend_macd_diff', 'trend_adx', 'momentum_rsi', 'momentum_ao', 'volatility_atr', 'volatility_bbw', 'volatility_dcw', 'volume_obv', 'volume_vwap']
# Empty DataFrame
# Columns: [datetime, close, trend_sma_fast, trend_sma_slow, trend_macd_diff, trend_adx, momentum_rsi, momentum_ao, volatility_atr, volatility_bbw, volatility_dcw, volume_obv, volume_vwap]
# Index: []
# 523239

# %% [markdown]
# ## Change point detection
# Change to pandas dataframe

# %%
# Dask version
# ddf["log_return"] = ddf["close"].map_partitions(np.log).diff().fillna(0)
# signal = (
#     ddf["log_return"]
#     .to_dask_array(lengths=True)  # Dask Array
#     .compute()  # NumPy Array
#     .reshape(-1, 1)
# )

# Also pandas version
ddf = ddf.repartition(partition_size="100MB")
df = ddf.compute()
df = df.sort_values("datetime")
df["log_return"] = np.log(df["close"]).diff().fillna(0)
signal = df["log_return"].values.reshape(-1, 1)

# %% [markdown]
# Compute trend_id

# %%
import importlib
import final_project_utils

importlib.reload(final_project_utils)
from final_project_utils import *

print_version()

break_times = add_trend_id(df, n_regimes=32, window_size=13 * 5 * 6.5, n_clusters=5)
print(df["trend_id"].unique())
# Out:
# LATEST!!!
# NumbaPerformanceWarning: Grid size 85 will likely result in GPU under-utilization due to low occupancy.
# [MP] done in 5.07s
# [FLUSS] 31 segments in 1.19s
#   0%|          | 0/32 [00:00<?, ?it/s]
# [FEAT] done in 0.01s
# [KMEANS] 5 clusters in 0.24s
# [0 1 2 0 0 0 3 0 4 0 0 4 0 0 0 4 0 0 4 0 4 0 0 0 4 0 0 0 4 0 0 4]
# [Timestamp('2016-01-21 23:00:00'), Timestamp('2018-09-09 22:00:00'), Timestamp('2019-03-08 05:00:00'), Timestamp('2019-03-25 20:00:00'), Timestamp('2019-04-15 23:00:00'), Timestamp('2019-05-05 23:00:00'), Timestamp('2019-07-28 20:00:00'), Timestamp('2019-08-15 11:00:00'), Timestamp('2019-09-07 22:00:00'), Timestamp('2019-09-27 10:00:00'), Timestamp('2019-10-15 00:00:00'), Timestamp('2019-11-07 02:00:00'), Timestamp('2019-11-24 17:00:00'), Timestamp('2019-12-12 08:00:00'), Timestamp('2019-12-29 23:00:00'), Timestamp('2020-01-25 17:00:00'), Timestamp('2020-02-12 08:00:00'), Timestamp('2020-02-29 23:00:00'), Timestamp('2020-03-25 13:00:00'), Timestamp('2020-04-13 00:00:00'), Timestamp('2020-05-08 16:00:00'), Timestamp('2020-05-27 00:00:00'), Timestamp('2020-06-13 14:00:00'), Timestamp('2020-07-02 13:00:00'), Timestamp('2020-07-28 12:00:00'), Timestamp('2020-08-17 22:00:00'), Timestamp('2020-09-07 20:00:00'), Timestamp('2020-09-25 10:00:00'), Timestamp('2020-10-21 12:00:00'), Timestamp('2020-11-08 22:00:00'), Timestamp('2020-11-26 13:00:00')]
# [0 1 2 3 4]

# %%
def save_break_points(bp_file, new_bps):
    # load existing as a set, or start empty
    if os.path.exists(bp_file):
        with open(bp_file, "rb") as f:
            break_points = set(pickle.load(f))
    else:
        break_points = set()

    # add new ones
    break_points |= set(new_bps)

    # overwrite back to disk
    with open(bp_file, "wb") as f:
        pickle.dump(break_points, f)


bp_file = "break_points.pkl"
save_break_points(bp_file, break_times)

# %% [markdown]
# Plot changepoints

# %% [markdown]
# # IMPLEMENTATION

# %%
import importlib
import final_project_utils

importlib.reload(final_project_utils)
from final_project_utils import *

print_version()
# Out:
# LATEST!!!

# %% [markdown]
# # EXPERIMENTATION

# %%
base_config = {
    # TRAINING PARAMETERS
    "log_dir": "./train_logs/base",
    "n_envs": 4,  # number of parallel environments to use for training
    "checkpoint": None,  # path to a checkpoint to load from
    "checkpoint_freq": 5000,  # save a model checkpoint every _ steps
    "eval_freq": 5000,  # evaluate the model every _ steps
    "n_eval_episodes": 10,  # number of episodes to evaluate the model on
    "n_train_timesteps": int(1e6),  # total number of training steps
    "verbose_training": True,
    # RL PARAMETERS (all set to defaults right now, except for seed)
    "policy_args": {
        "net_arch": [64, 64],
        "activation_fn": nn.ReLU,
    },
    "algo_kwargs": {
        "learning_rate": 1e-4,
        "buffer_size": int(1e6),
        "learning_starts": 100,  # how many steps of the model to collect transitions for before learning starts
        "batch_size": 32,
        "tau": 1.0,  # the soft update coefficient ("Polyak update", between 0 and 1) default 1 for hard update
        "gamma": 0.99,
        "train_freq": (4, "step"),  # Update the model every ``train_freq`` steps.
        "gradient_steps": 1,  # How many gradient steps to do after each rollout
        "target_update_interval": int(
            1e4
        ),  # update the target network every ``target_update_interval`` environment steps.
        # DQN only
        # "exploration_fraction": 0.1,  # fraction of entire training period over which the exploration rate is reduced
        # "exploration_initial_eps": 1.0,  # initial value of random action probability
        # "exploration_final_eps": 0.05,  # final value of random action probability
        "seed": 42,
    },
}

fifo_config = base_config.copy()
fifo_config["log_dir"] = "./train_logs/fifo"
fifo_config["algo_kwargs"]["replay_buffer_class"] = ReplayBuffer
# fifo_config["algo_kwargs"]["device"] = "cuda" if torch.cuda.is_available() else "cpu"

df_features = df.drop(columns=["datetime"])
# stock_data = {"SPY": df_features}
stock_data = df_features


def make_env():
    return StockTradingEnv(stock_data)


def make_eval_env():
    return StockTradingEnv(stock_data)  # could be different data if desired


print(f"Number of ticks in SPY data: {len(df_features)}")
# Out:
# Number of ticks in SPY data: 523239

# %%
import importlib
import final_project_utils

importlib.reload(final_project_utils)
from final_project_utils import *

print_version()

# Cleanup
IPython.display.clear_output(wait=True)
gc.collect()

env = DummyVecEnv([make_env])
obs = env.reset()
print(f"Observation shape: {obs.shape}")
print(f"Observation space: {env.observation_space}")
print(f"Action space: {env.action_space}")

# Create a simple SAC model
log_dir = "./train_logs/simple_sac"
os.makedirs(log_dir, exist_ok=True)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

model = SAC(
    "MlpPolicy",
    env,
    learning_rate=1e-3,
    buffer_size=int(1e6),
    batch_size=256,
    replay_buffer_class=ReplayBuffer,
    verbose=1,
    tensorboard_log=log_dir,
    device=device,
)

# model = DQN(
#     "MlpPolicy",
#     env,
#     learning_rate=1e-3,
#     buffer_size=int(1e6),
#     batch_size=256,
#     replay_buffer_class=ReplayBuffer,
#     verbose=1,
#     tensorboard_log=log_dir,
#     device=device,
# )

# Train for a small number of steps\r
try:
    print("\nStarting simple training...")
    def policy_l2(model):
        return sum((p.data**2).sum().item() for p in model.policy.parameters())**0.5
    print("L2 before:", policy_l2(model))
    model.learn(total_timesteps=2000, progress_bar=True)
    print("L2 after :", policy_l2(model))
    print("Training completed successfully!")
except Exception as e:
    print(f"Training failed with error: {e}")
    print(f"Policy network input shape: {model.policy.observation_space.shape}")
    print(f"Environment observation shape example: {obs.shape}")
    try:
        print("\nPolicy architecture:")
        print(model.policy)
    except:
        print("Could not print policy architecture")
    IPython.display.clear_output(wait=True)
# Out:
# Observation shape: (1, 19)
# Observation space: Box(-inf, inf, (19,), float32)
# Action space: Box(-1.0, 1.0, (1,), float32)
# Using device: cuda
# Using cuda device
#
# Starting simple training...
# L2 before: 29.585110566093658
# Logging to ./train_logs/simple_sac\SAC_16
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# L2 after : 30.83452393652723
# Training completed successfully!

# %%
reset_out = env.reset()  # ← Gymnasium may give (obs, info); SB3 VecEnv gives obs
print("Got:", reset_out)  # see whether it’s a tuple
print("Is tuple?", isinstance(reset_out, tuple))
# Out:
# Got: [[1.9913000e+02 1.9899667e+02 1.9890538e+02 4.2707819e-02 1.7579311e+01
#   5.5665184e+01 1.4279412e-01 1.4706543e-01 2.2915116e-01 2.9654649e-01
#   1.4393072e+08 1.9901184e+02 0.0000000e+00 0.0000000e+00 1.0000000e+06
#   0.0000000e+00 1.0000000e+06 1.0000000e+06 0.0000000e+00]]
# Is tuple? False

# %%
# import importlib
# import final_project_utils

# importlib.reload(final_project_utils)
# from final_project_utils import *

# print_version()

# After training your model
print("\nTesting model...")
test_results = test_model(env, model, n_tests=200)

# Plot the results
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

# Portfolio value over time
plt.subplot(2, 1, 1)
plt.plot(test_results["steps"], test_results["net_worths"])
plt.title("Portfolio Performance")
plt.xlabel("Step")
plt.ylabel("Net Worth ($)")
plt.grid(True, alpha=0.3)

# Cumulative rewards
plt.subplot(2, 1, 2)
plt.plot(test_results["steps"], test_results["cumulative_rewards"])
plt.title("Cumulative Rewards")
plt.xlabel("Step")
plt.ylabel("Reward")

plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Testing model...
#
# Performance Summary:
# Initial Net Worth: $995000.10
# Final Net Worth: $997374.58
# Profit/Loss: $2374.48 (0.24%)

# %%
# Basic imports
import numpy as np
import os
import torch
from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv
import time
from final_project_utils import SERReplayBuffer  # Import custom replay buffer

# Clear any previous outputs

IPython.display.clear_output(wait=True)

# Force garbage collection

gc.collect()

env = DummyVecEnv([make_env])
obs = env.reset()
obs = (
    obs.squeeze()
)  # This removes the batch dimension, making it (19,) instead of (1, 19)

print(f"Observation shape: {obs.shape}")
print(f"Observation space: {env.observation_space}")
print(f"Action space: {env.action_space}")

# Create a simple SAC model with SER
log_dir = "./train_logs/ser_simple"
os.makedirs(log_dir, exist_ok=True)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# SER configuration
strategy = "surprise"  # Options: "reward", "distribution", "surprise", "coverage"
priority_queue_size = 5000
priority_queue_percent = 0.5

# Create the model with custom replay buffer
model = SAC(
    "MlpPolicy",
    env,
    learning_rate=1e-3,
    buffer_size=10000,
    batch_size=256,
    verbose=1,
    tensorboard_log=log_dir,
    device=device,
    replay_buffer_class=SERReplayBuffer,
    replay_buffer_kwargs={
        "strategy": strategy,
        "priority_queue_size": priority_queue_size,
        "priority_queue_percent": priority_queue_percent,
    },
)

# Set Q-networks for SERReplayBuffer
if isinstance(model.replay_buffer, SERReplayBuffer):
    print("Setting Q-networks for SERReplayBuffer...")
    model.replay_buffer.set_q_nets(model.critic.qf0, model.critic_target.qf0)

# Train for a small number of steps
try:
    print("\nStarting simple training with SER...")
    model.learn(total_timesteps=5000, progress_bar=True)
    print("Training completed successfully!")
except KeyboardInterrupt:
    print("\nTraining interrupted by user! Saving current model...")
    interrupted_save_path = os.path.join(
        log_dir, f"interrupted_model_{int(time.time())}"
    )
    model.save(interrupted_save_path)
    print(f"Model saved to {interrupted_save_path}")

    # Force the progress bar to close
    IPython.display.clear_output(wait=True)
    print("Progress bar cleaned up after interruption.")

except Exception as e:
    print(f"Training failed with error: {e}")

    # Print more diagnostic information
    print("\nDiagnostic information:")
    print(f"Policy network input shape: {model.policy.observation_space.shape}")
    print(f"Environment observation shape example: {obs.shape}")

    # Try to print the policy architecture
    try:
        print("\nPolicy architecture:")
        print(model.policy)
    except:
        print("Could not print policy architecture")
finally:
    # This will always run, ensuring cleanup
    env.close()
    print("Environment closed.")
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Observation shape: (19,)
# Observation space: Box(-inf, inf, (19,), float32)
# Action space: Box(-1.0, 1.0, (1,), float32)
# Using device: cuda
# Using cuda device
# Setting Q-networks for SERReplayBuffer...
#
# Starting simple training with SER...
# Logging to ./train_logs/ser_simple\SAC_2
# Output()
# Training failed with error: mat1 and mat2 shapes cannot be multiplied (1x19 and 20x256)
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:
# Diagnostic information:Environment closed.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[25], line 66
#      65 print("\nStarting simple training with SER...")
# ---> 66 model.learn(total_timesteps=5000, progress_bar=True)
#      67 print("Training completed successfully!")
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\stable_baselines3\sac\sac.py:308, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfSAC,
#     301     total_timesteps: int,
#    (...)    306     progress_bar: bool = False,
#     307 ) -> SelfSAC:
# --> 308     return super().learn(
#     309         total_timesteps=total_timesteps,
#     310         callback=callback,
#     311         log_interval=log_interval,
#     312         tb_log_name=tb_log_name,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314         progress_bar=progress_bar,
#     315     )
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:328, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     327 while self.num_timesteps < total_timesteps:
# --> 328     rollout = self.collect_rollouts(
#     329         self.env,
#     330         train_freq=self.train_freq,
#     331         action_noise=self.action_noise,
#     332         callback=callback,
#     333         learning_starts=self.learning_starts,
#     334         replay_buffer=self.replay_buffer,
#     335         log_interval=log_interval,
#     336     )
#     338     if not rollout.continue_training:
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:575, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     574 # Store data in replay buffer (normalized action and unnormalized observation)
# --> 575 self._store_transition(replay_buffer, buffer_actions, new_obs, rewards, dones, infos)  # type: ignore[arg-type]
#     577 self._update_current_progress_remaining(self.num_timesteps, self._total_timesteps)
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:492, in OffPolicyAlgorithm._store_transition(self, replay_buffer, buffer_action, new_obs, reward, dones, infos)
#     490                 next_obs[i] = self._vec_normalize_env.unnormalize_obs(next_obs[i, :])  # type: ignore[assignment]
# --> 492 replay_buffer.add(
#     493     self._last_original_obs,  # type: ignore[arg-type]
#     494     next_obs,  # type: ignore[arg-type]
#     495     buffer_action,
#     496     reward_,
#     497     dones,
#     498     infos,
#     499 )
#     501 self._last_obs = new_obs
#
# File c:\Users\john\Documents\DATA\programming_dirty\comp579_w25\comp579_project\final_project_utils.py:526, in SERReplayBuffer.add(self, obs, next_obs, action, reward, done, infos)
#     525 for env_idx in range(self.n_envs):
# --> 526     score = self.compute_score(
#     527         obs[env_idx],
#     528         next_obs[env_idx],
#     529         action[env_idx],
#     530         reward[env_idx],
#     531         done[env_idx],
#     532     )
#     533     heapq.heappush(self.long_term_memory, (score, idx, env_idx))
#
# File c:\Users\john\Documents\DATA\programming_dirty\comp579_w25\comp579_project\final_project_utils.py:643, in SERReplayBuffer.compute_score(self, obs, next_obs, action, reward, done)
#     641 done_tensor = self.to_torch(done).unsqueeze(0).float()
# --> 643 q_values = self.q_net(obs_tensor)
#     644 q_sa = q_values.gather(1, action_tensor)
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\torch\nn\modules\container.py:240, in Sequential.forward(self, input)
#     239 for module in self:
# --> 240     input = module(input)
#     241 return input
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1x19 and 20x256)
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\console.py:1693, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1692 with self:
# -> 1693     renderables = self._collect_renderables(
#    1694         objects,
#    1695         sep,
#    1696         end,
#    1697         justify=justify,
#    1698         emoji=emoji,
#    1699         markup=markup,
#    1700         highlight=highlight,
#    1701     )
#    1702     for hook in render_hooks:
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\console.py:1553, in Console._collect_renderables(self, objects, sep, end, justify, emoji, markup, highlight)
#    1551 if isinstance(renderable, str):
#    1552     append_text(
# -> 1553         self.render_str(
#    1554             renderable,
#    1555             emoji=emoji,
#    1556             markup=markup,
#    1557             highlight=highlight,
#    1558             highlighter=_highlighter,
#    1559         )
#    1560     )
#    1561 elif isinstance(renderable, Text):
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\console.py:1465, in Console.render_str(self, text, style, justify, overflow, emoji, markup, highlight, highlighter)
#    1464 if _highlighter is not None:
# -> 1465     highlight_text = _highlighter(str(rich_text))
#    1466     highlight_text.copy_styles(rich_text)
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\highlighter.py:38, in Highlighter.__call__(self, text)
#      37     raise TypeError(f"str or Text instance required, not {text!r}")
# ---> 38 self.highlight(highlight_text)
#      39 return highlight_text
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\highlighter.py:77, in RegexHighlighter.highlight(self, text)
#      76 for re_highlight in self.highlights:
# ---> 77     highlight_regex(re_highlight, style_prefix=self.base_style)
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\text.py:617, in Text.highlight_regex(self, re_highlight, style, style_prefix)
#     616 if isinstance(re_highlight, str):
# --> 617     re_highlight = re.compile(re_highlight)
#     618 for match in re_highlight.finditer(plain):
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\re\__init__.py:228, in compile(pattern, flags)
#     227 "Compile a regular expression pattern, returning a Pattern object."
# --> 228 return _compile(pattern, flags)
#
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# Cell In[25], line 84
#      81 print(f"Training failed with error: {e}")
#      83 # Print more diagnostic information
# ---> 84 print("\nDiagnostic information:")
#      85 print(f"Policy network input shape: {model.policy.observation_space.shape}")
#      86 print(f"Environment observation shape example: {obs.shape}")
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\file_proxy.py:43, in FileProxy.write(self, text)
#      41 if lines:
#      42     console = self.__console
# ---> 43     with console:
#      44         output = Text("\n").join(
#      45             self.__ansi_decoder.decode_line(line) for line in lines
#      46         )
#      47         console.print(output)
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\console.py:866, in Console.__exit__(self, exc_type, exc_value, traceback)
#     864 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     865     """Exit buffer context."""
# --> 866     self._exit_buffer()
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\console.py:824, in Console._exit_buffer(self)
#     822 """Leave buffer context, and render content if required."""
#     823 self._buffer_index -= 1
# --> 824 self._check_buffer()
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\console.py:2033, in Console._check_buffer(self)
#    2030     return
#    2032 try:
# -> 2033     self._write_buffer()
#    2034 except BrokenPipeError:
#    2035     self.on_broken_pipe()
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\console.py:2049, in Console._write_buffer(self)
#    2046 if self.is_jupyter:  # pragma: no cover
#    2047     from .jupyter import display
# -> 2049     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2050     del self._buffer[:]
#    2051 else:
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\console.py:1692, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1690     crop = False
#    1691 render_hooks = self._render_hooks[:]
# -> 1692 with self:
#    1693     renderables = self._collect_renderables(
#    1694         objects,
#    1695         sep,
#    (...)   1700         highlight=highlight,
#    1701     )
#    1702     for hook in render_hooks:
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\console.py:866, in Console.__exit__(self, exc_type, exc_value, traceback)
#     864 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     865     """Exit buffer context."""
# --> 866     self._exit_buffer()
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\console.py:824, in Console._exit_buffer(self)
#     822 """Leave buffer context, and render content if required."""
#     823 self._buffer_index -= 1
# --> 824 self._check_buffer()
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\console.py:2033, in Console._check_buffer(self)
#    2030     return
#    2032 try:
# -> 2033     self._write_buffer()
#    2034 except BrokenPipeError:
#    2035     self.on_broken_pipe()
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\console.py:2049, in Console._write_buffer(self)
#    2046 if self.is_jupyter:  # pragma: no cover
#    2047     from .jupyter import display
# -> 2049     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2050     del self._buffer[:]
#    2051 else:
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\console.py:1692, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1690     crop = False
#    1691 render_hooks = self._render_hooks[:]
# -> 1692 with self:
#    1693     renderables = self._collect_renderables(
#    1694         objects,
#    1695         sep,
#    (...)   1700         highlight=highlight,
#    1701     )
#    1702     for hook in render_hooks:
#
#     [... skipping similar frames: Console.__exit__ at line 866 (268 times), Console._check_buffer at line 2033 (268 times), Console._exit_buffer at line 824 (268 times), Console._write_buffer at line 2049 (268 times), ZMQDisplayPublisher._flush_streams at line 66 (267 times), display at line 91 (267 times), display at line 285 (267 times), FileProxy.flush at line 53 (267 times), Console.print at line 1692 (267 times), ZMQDisplayPublisher.publish at line 103 (267 times), publish_display_data at line 73 (267 times)]
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\console.py:1692, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1690     crop = False
#    1691 render_hooks = self._render_hooks[:]
# -> 1692 with self:
#    1693     renderables = self._collect_renderables(
#    1694         objects,
#    1695         sep,
#    (...)   1700         highlight=highlight,
#    1701     )
#    1702     for hook in render_hooks:
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\console.py:866, in Console.__exit__(self, exc_type, exc_value, traceback)
#     864 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     865     """Exit buffer context."""
# --> 866     self._exit_buffer()
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\console.py:824, in Console._exit_buffer(self)
#     822 """Leave buffer context, and render content if required."""
#     823 self._buffer_index -= 1
# --> 824 self._check_buffer()
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\console.py:2033, in Console._check_buffer(self)
#    2030     return
#    2032 try:
# -> 2033     self._write_buffer()
#    2034 except BrokenPipeError:
#    2035     self.on_broken_pipe()
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\console.py:2049, in Console._write_buffer(self)
#    2046 if self.is_jupyter:  # pragma: no cover
#    2047     from .jupyter import display
# -> 2049     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2050     del self._buffer[:]
#    2051 else:
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\jupyter.py:86, in display(segments, text)
#      84 def display(segments: Iterable[Segment], text: str) -> None:
#      85     """Render segments to Jupyter."""
# ---> 86     html = _render_segments(segments)
#      87     jupyter_renderable = JupyterRenderable(html, text)
#      88     try:
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.9\Lib\site-packages\rich\jupyter.py:67, in _render_segments(segments)
#      65 append_fragment = fragments.append
#      66 theme = DEFAULT_TERMINAL_THEME
# ---> 67 for text, style, control in Segment.simplify(segments):
#      68     if control:
#      69         continue
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# ### FIFO only

# %%
print("cuda" if torch.cuda.is_available() else "cpu")
try:
    train(make_env, make_eval_env, fifo_config)
except Exception as e:
    print(f"Error during training: {e}")

# %%
plot_evaluations(fifo_config["log_dir"])

# %% [markdown]
# ### SER

# %%
env = DummyVecEnv([make_env])
print(f"Observation space: {env.observation_space}")
print(f"Shape: {env.observation_space.shape}")

# Also check what's actually coming from the environment
obs = env.reset()
print(f"Actual observation shape: {obs.shape}")
# Out:
# Observation space: Box(-inf, inf, (19,), float32)
# Shape: (19,)
# Actual observation shape: (1, 19)

# %%
ser_config = base_config.copy()
ser_config["log_dir"] = "./train_logs/ser"
ser_config["algo_kwargs"]["replay_buffer_class"] = SERReplayBuffer

ser_config["strategy"] = "surprise"
ser_config["priority_queue_size"] = 5000
ser_config["priority_queue_percent"] = 0.5


ser_config["algo_kwargs"]["replay_buffer_kwargs"] = {
    "strategy": ser_config["strategy"],
    "priority_queue_size": ser_config["priority_queue_size"],
    "priority_queue_percent": ser_config["priority_queue_percent"],
}

import IPython.display

IPython.display.clear_output(wait=True)

# Also try to force garbage collection
import gc

gc.collect()

train(make_env, make_eval_env, ser_config)
# Out:
# Initializing...
# Algorithm kwargs:
#   learning_rate: 0.0001
#   buffer_size: 1000000
#   learning_starts: 100
#   batch_size: 32
#   tau: 1.0
#   gamma: 0.99
#   train_freq: (4, 'step')
#   gradient_steps: 1
#   target_update_interval: 10000
#   seed: 42
#   replay_buffer_class: <class 'final_project_utils.SERReplayBuffer'>
#   replay_buffer_kwargs: {'strategy': 'surprise', 'priority_queue_size': 5000, 'priority_queue_percent': 0.5}
# Output()
# Training finished or interrupted.
# Training...

# %%
plot_evaluations(ser_config["log_dir"])
# Out:
# Evaluations: min: 0.0, max: 0.0, std: 0.0

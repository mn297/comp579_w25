# %%
# !pip install yfinance pandas pandas_ta gym-anytrading
# Out:
# Requirement already satisfied: yfinance in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (0.2.55)
# Requirement already satisfied: pandas in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (2.2.2)
# Requirement already satisfied: pandas_ta in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (0.3.14b0)
# Collecting gym-anytrading
#   Downloading gym_anytrading-2.0.0-py3-none-any.whl.metadata (292 bytes)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: gymnasium>=0.29.1 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from gym-anytrading) (1.0.0)
# Requirement already satisfied: matplotlib>=3.1.1 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from gym-anytrading) (3.9.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from gymnasium>=0.29.1->gym-anytrading) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from gymnasium>=0.29.1->gym-anytrading) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from gymnasium>=0.29.1->gym-anytrading) (0.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from matplotlib>=3.1.1->gym-anytrading) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from matplotlib>=3.1.1->gym-anytrading) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from matplotlib>=3.1.1->gym-anytrading) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from matplotlib>=3.1.1->gym-anytrading) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from matplotlib>=3.1.1->gym-anytrading) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from matplotlib>=3.1.1->gym-anytrading) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from matplotlib>=3.1.1->gym-anytrading) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\john\.pyenv\pyenv-win\versions\3.12.4\lib\site-packages (from requests>=2.31->yfinance) (2024.7.4)
# Downloading gym_anytrading-2.0.0-py3-none-any.whl (172 kB)
# Installing collected packages: gym-anytrading
# Successfully installed gym-anytrading-2.0.0

# %%
import gymnasium as gym
import gym_anytrading
from gym_anytrading.envs import StocksEnv  # Or ForexEnv, TradingEnv

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import logging
import os
from datetime import datetime

# --- Import yfinance ---
import yfinance as yf

from stable_baselines3 import SAC
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.buffers import ReplayBuffer  # Default FIFO-like buffer

# Placeholder for your future custom buffer
# from replay_buffers.selective_replay import SelectiveReplayBuffer

# Configure logging and warnings
logging.basicConfig(level=logging.INFO)
warnings.filterwarnings("ignore", category=FutureWarning)
# Suppress specific yfinance warnings if needed
# logging.getLogger('yfinance').setLevel(logging.ERROR)


# --- Configuration ---
config = {
    "env_id": "stocks-v0",  # ID for StocksEnv in gym_anytrading
    # --- Data Source Configuration ---
    "ticker": "MSFT",  # Stock ticker (e.g., Microsoft)
    "start_date": "2018-01-01",  # Data start date
    "end_date": "2023-12-31",  # Data end date
    # --- End Data Source Config ---
    "window_size": 15,  # Observation window size (increased slightly)
    "start_tick": None,  # Starting index in data (None = beginning, respecting window_size)
    "end_tick": None,  # Ending index in data (None = end)
    "initial_balance": 10000,  # Starting cash
    "use_ser": False,  # Set to True to use SER buffer later
    "ser_strategy": "reward",  # 'surprise', 'reward', 'global_match', 'coverage'
    "sac_policy": "MlpPolicy",
    "total_timesteps": 100000,  # Increased timesteps for more realistic data
    "learning_rate": 3e-4,  # Default SAC learning rate
    "buffer_size": 50000,  # Increased Replay buffer size
    "batch_size": 256,  # SAC batch size
    "tau": 0.005,  # SAC target smoothing coefficient
    "gamma": 0.99,  # Discount factor
    "log_interval": 1000,  # Log training progress interval
    "model_save_path": "models/",  # Directory to save trained models
    "results_path": "results/",  # Directory for results/plots
}


# --- Placeholder for Change Point Detection ---
# (Same as before - keep as placeholder)
def detect_change_points(df, method="pelt"):
    logging.info("Change Point Detection placeholder called.")
    return []


# --- Placeholder for Custom Selective Experience Replay Buffer ---
# (Same as before - keep as placeholder, move to separate file later)
class SelectiveReplayBuffer(ReplayBuffer):
    def __init__(self, *args, prioritization_strategy="reward", **kwargs):
        super().__init__(*args, **kwargs)
        self.prioritization_strategy = prioritization_strategy
        self.task_id = 0
        logging.info(
            f"Initialized SelectiveReplayBuffer (Placeholder) with strategy: {self.prioritization_strategy}"
        )

    def add(self, obs, next_obs, action, reward, done, infos):
        super().add(
            obs=obs,
            next_obs=next_obs,
            action=action,
            reward=reward,
            done=done,
            infos=infos,
        )

    def sample(self, batch_size, env=None):
        logging.debug(
            f"SER Sampling (Placeholder) using strategy: {self.prioritization_strategy}"
        )
        return super().sample(batch_size=batch_size, env=env)

    def set_task_id(self, task_id):
        self.task_id = task_id
        logging.info(f"SER Buffer task ID set to: {self.task_id}")


# --- Helper Function to Create Environment ---
# (Same as before)
def make_custom_env(df, window_size, start_tick, end_tick, initial_balance, task_id=0):
    if start_tick is None:
        start_tick = window_size
    if end_tick is None:
        end_tick = len(df) - 1

    if start_tick >= end_tick:
        raise ValueError(
            f"start_tick ({start_tick}) must be less than end_tick ({end_tick})"
        )
    if start_tick < window_size:
        logging.warning(
            f"start_tick ({start_tick}) is less than window_size ({window_size}). Adjusting start_tick."
        )
        start_tick = window_size

    logging.info(
        f"Creating env for ticks: {start_tick} to {end_tick} (Total data points: {len(df)})"
    )

    env = gym.make(
        config["env_id"],
        df=df,
        window_size=window_size,
        frame_bound=(start_tick, end_tick),
        # render_mode='human' # Use 'human' to watch, 'rgb_array' or None for faster training
    )
    return env

# %%
# 1. Load Data using yfinance
logging.info(
    f"Downloading {config['ticker']} data from {config['start_date']} to {config['end_date']}..."
)
try:
    df = yf.download(
        config["ticker"],
        start=config["start_date"],
        end=config["end_date"],
        progress=True,
    )  # Show download progress

    if df.empty:
        raise ValueError(
            f"No data found for ticker {config['ticker']} in the specified date range."
        )

    # Ensure required columns are present (yfinance usually names them correctly)
    required_cols = ["Open", "High", "Low", "Close", "Volume"]
    if not all(col in df.columns for col in required_cols):
        raise ValueError(
            f"Downloaded data missing required columns. Found: {df_processed.columns.tolist()}"
        )

    # Handle potential missing values (e.g., non-trading days might yield NaNs if requesting specific dates)
    df.dropna(inplace=True)

    if df.empty:
        raise ValueError("DataFrame became empty after dropping NaNs.")

    df_processed = df.copy()

    logging.info(f"Data downloaded successfully. Shape: {df_processed.shape}")
    logging.info(f"Data Head:\n{df_processed.head()}")
    logging.info(f"Data Tail:\n{df_processed.tail()}")


except Exception as e:
    logging.error(f"Failed to download or process data: {e}", exc_info=True)
    # Exit if data loading fails
    exit()

# 2. (Optional) Perform Change Point Detection (on the full dataset)
change_points = detect_change_points(df_processed)
# For now, we'll train on the whole dataset as one task

# 3. Create Environment
# Using the full dataset loaded via yfinance
train_env = make_custom_env(
    df=df_processed,
    window_size=config["window_size"],
    start_tick=config["start_tick"],  # Will default based on window_size
    end_tick=config["end_tick"],  # Will default to len(df) - 1
    initial_balance=config["initial_balance"],
)
# Wrap in a VecEnv for SB3
train_vec_env = make_vec_env(lambda: train_env, n_envs=1)

# 4. Setup Replay Buffer
if config["use_ser"]:
    buffer_class = SelectiveReplayBuffer
    buffer_kwargs = dict(prioritization_strategy=config["ser_strategy"])
else:
    buffer_class = ReplayBuffer
    buffer_kwargs = {}

# 5. Initialize Agent
model = SAC(
    config["sac_policy"],
    train_vec_env,
    verbose=1,
    learning_rate=config["learning_rate"],
    buffer_size=config["buffer_size"],
    batch_size=config["batch_size"],
    tau=config["tau"],
    gamma=config["gamma"],
    replay_buffer_class=buffer_class,
    replay_buffer_kwargs=buffer_kwargs,
    tensorboard_log="./tensorboard_logs/",  # For visualizing training
    # seed=42 # Set for reproducibility if needed
)

# 6. Train Agent
logging.info(f"Starting training for {config['total_timesteps']} timesteps...")
start_time = datetime.now()
try:
    model.learn(
        total_timesteps=config["total_timesteps"],
        log_interval=config["log_interval"],  # Log every N calls to `learn()`
        tb_log_name=f"SAC_{'SER' if config['use_ser'] else 'FIFO'}_{config['ticker']}_{datetime.now().strftime('%Y%m%d_%H%M')}",
    )
except Exception as e:
    logging.error(f"Error during training: {e}", exc_info=True)
finally:
    # Ensure environment is closed even if error occurs
    try:
        train_vec_env.close()
    except Exception as env_close_e:
        logging.error(f"Error closing environment: {env_close_e}")

end_time = datetime.now()
logging.info(f"Training finished. Duration: {end_time - start_time}")

# 7. Save Model
os.makedirs(config["model_save_path"], exist_ok=True)
model_name = f"sac_{'ser' if config['use_ser'] else 'fifo'}_{config['ticker']}_{config['total_timesteps']}steps_{datetime.now().strftime('%Y%m%d_%H%M')}"
save_path = os.path.join(config["model_save_path"], model_name)
model.save(save_path)
logging.info(f"Model saved to {save_path}.zip")  # SB3 automatically adds .zip

# --- Next Steps ---
# (Same as before, but now you have real data)
# 1. Implement the `SelectiveReplayBuffer` class fully.
# 2. Implement actual CPD.
# 3. Adapt for sequential training (markets/trends).
# 4. Implement evaluation script.
# 5. Add plotting and analysis.

logging.info("Script execution finished with real data.")
# Out:
# INFO:root:Downloading MSFT data from 2018-01-01 to 2023-12-31...
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# INFO:root:Data downloaded successfully. Shape: (1509, 5)
# INFO:root:Data Head:
# Price           Close       High        Low       Open    Volume
# Ticker           MSFT       MSFT       MSFT       MSFT      MSFT
# Date
# 2018-01-02  79.474152  79.807028  79.058059  79.640590  22483800
# 2018-01-03  79.844017  79.991965  79.492650  79.575866  26061400
# 2018-01-04  80.546761  81.055324  80.047446  80.065936  21912000
# 2018-01-05  81.545418  81.748843  80.842677  81.055351  23407100
# 2018-01-08  81.628601  81.906001  80.999835  81.554627  22113000
# INFO:root:Data Tail:
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2023-12-22  371.055695  371.650055  369.203294  370.164168  17091100
# 2023-12-26  371.134949  373.393496  369.985859  371.471746  12673100
# 2023-12-27  370.550537  371.531213  369.302382  370.174108  14905400
# 2023-12-28  371.749084  372.917975  370.639627  371.838234  14327000
# 2023-12-29  372.501953  373.611411  369.966042  372.462321  18723000
# INFO:root:Change Point Detection placeholder called.
# INFO:root:Creating env for ticks: 15 to 1508 (Total data points: 1509)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 49
#      44 change_points = detect_change_points(df_processed)
#      45 # For now, we'll train on the whole dataset as one task
#      46
#      47 # 3. Create Environment
#      48 # Using the full dataset loaded via yfinance
# ---> 49 train_env = make_custom_env(
#      50     df=df_processed,
#      51     window_size=config["window_size"],
#      52     start_tick=config["start_tick"],  # Will default based on window_size
#      53     end_tick=config["end_tick"],  # Will default to len(df) - 1
#      54     initial_balance=config["initial_balance"],
#      55 )
#      56 # Wrap in a VecEnv for SB3
#      57 train_vec_env = make_vec_env(lambda: train_env, n_envs=1)
#
# Cell In[2], line 118, in make_custom_env(df, window_size, start_tick, end_tick, initial_balance, task_id)
#     112     start_tick = window_size
#     114 logging.info(
#     115     f"Creating env for ticks: {start_tick} to {end_tick} (Total data points: {len(df)})"
#     116 )
# --> 118 env = gym.make(
#     119     config["env_id"],
#     120     df=df,
#     121     window_size=window_size,
#     122     frame_bound=(start_tick, end_tick),
#     123     # render_mode='human' # Use 'human' to watch, 'rgb_array' or None for faster training
#     124 )
#     125 return env
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.4\Lib\site-packages\gymnasium\envs\registration.py:740, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     734         logger.warn(
#     735             f"The environment is being initialised with render_mode={render_mode!r} "
#     736             f"that is not in the possible render_modes ({render_modes})."
#     737         )
#     739 try:
# --> 740     env = env_creator(**env_spec_kwargs)
#     741 except TypeError as e:
#     742     if (
#     743         str(e).find("got an unexpected keyword argument 'render_mode'") >= 0
#     744         and apply_human_rendering
#     745     ):
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.4\Lib\site-packages\gym_anytrading\envs\stocks_env.py:12, in StocksEnv.__init__(self, df, window_size, frame_bound, render_mode)
#       9 assert len(frame_bound) == 2
#      11 self.frame_bound = frame_bound
# ---> 12 super().__init__(df, window_size, render_mode)
#      14 self.trade_fee_bid_percent = 0.01  # unit
#      15 self.trade_fee_ask_percent = 0.005
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.4\Lib\site-packages\gym_anytrading\envs\trading_env.py:35, in TradingEnv.__init__(self, df, window_size, render_mode)
#      33 self.df = df
#      34 self.window_size = window_size
# ---> 35 self.prices, self.signal_features = self._process_data()
#      36 self.shape = (window_size, self.signal_features.shape[1])
#      38 # spaces
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.4\Lib\site-packages\gym_anytrading\envs\stocks_env.py:24, in StocksEnv._process_data(self)
#      21 prices = prices[self.frame_bound[0]-self.window_size:self.frame_bound[1]]
#      23 diff = np.insert(np.diff(prices), 0, 0)
# ---> 24 signal_features = np.column_stack((prices, diff))
#      26 return prices.astype(np.float32), signal_features.astype(np.float32)
#
# File c:\Users\john\.pyenv\pyenv-win\versions\3.12.4\Lib\site-packages\numpy\lib\shape_base.py:652, in column_stack(tup)
#     650         arr = array(arr, copy=False, subok=True, ndmin=2).T
#     651     arrays.append(arr)
# --> 652 return _nx.concatenate(arrays, 1)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 1508 and the array at index 1 has size 1

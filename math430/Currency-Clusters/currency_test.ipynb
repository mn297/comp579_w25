# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
import scipy.stats as stats
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import SpectralClustering
from sklearn.neighbors import NearestNeighbors
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import currency_clustering_utils

# %%
data = pd.read_csv("FX_EURUSD30.csv")
data['datetime_utc'] = pd.to_datetime(data['time'], unit='s', utc=True)
data['datetime_est'] = data['datetime_utc'].dt.tz_convert('US/Eastern')
print(data['datetime_est'].min())
print(data['datetime_est'].max())
# Out:
# 2022-01-02 17:00:00-05:00
# 2023-12-03 22:30:00-05:00

# %%
df = pd.read_csv("FX_EURUSD30.csv")
currency_clustering_utils.plot_ticks(df)

# %%
currency_clustering_utils.find_optimal_clustering(df)
# Out:
# Finding optimal clusters: 100%|██████████| 16/16 [01:48<00:00,  6.80s/it]
# {'silhouette': 7, 'davies_bouldin': 7, 'elbow': np.int64(6)}
